# %%
import pymongo
import requests  
import json

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["bookstore"]
# 获取数据库中的所有集合名称
collection_names = db.list_collection_names()

# 打印集合名称
for collection_name in collection_names:
    print(collection_name)
# Out:
# user_store
# book
# new_order
# store
# user

# %%
cur = db["user"]
result = cur.find({"user_id": "Airthe911"})
# cur.delete_one({"user_id": "Airthe911"})
print(result.count())
for each in result:
    print(each)
# Out:
# 0
# C:\Users\Airthe911\AppData\Local\Temp\ipykernel_25076\3773791079.py:4: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   print(result.count())

# %%
url = 'http://127.0.0.1:5000/auth/register'
data = {  
    "user_id": "Airthe911",  
    "password": "091101"  
}  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  

response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json() 
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
url = 'http://127.0.0.1:5000/auth/login'
  
data = {  
    "user_id": "Airthe911",  
    "password": "091101",
    "terminal": "PC"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok', 'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiQWlydGhlOTExIiwidGVybWluYWwiOiJQQyIsInRpbWVzdGFtcCI6MTY5ODQyMTAwMC44NjE0NDUyfQ.eC1p_pj_U2Kafe8kpHjXS19Y-hs3SVtT5s0O6bww6I8'}

# %%
url = 'http://127.0.0.1:5000/auth/logout'
  
data = {  
    "user_id": "Airthe911",  
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json',
    "token": 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiQWlydGhlOTExIiwidGVybWluYWwiOiJQQyIsInRpbWVzdGFtcCI6MTY5ODQyMTAwMC44NjE0NDUyfQ.eC1p_pj_U2Kafe8kpHjXS19Y-hs3SVtT5s0O6bww6I8'
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
url = 'http://127.0.0.1:5000/auth/password'
  
data = {  
    "user_id": "Airthe911",  
    "oldPassword": "091101",
    "newPassword": "123456"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json',
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
url = 'http://127.0.0.1:5000/auth/login'
  
data = {  
    "user_id": "Airthe911",  
    "password": "123456",
    "terminal": "PC"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok', 'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiQWlydGhlOTExIiwidGVybWluYWwiOiJQQyIsInRpbWVzdGFtcCI6MTY5ODQyMTEyNy42NTE5MDM0fQ._U25VW-L8d8Opysjxj-CV3Wm2XeZozxhHNiQDZvyR3U'}

# %%
url = 'http://127.0.0.1:5000/auth/logout'
  
data = {  
    "user_id": "Airthe911",  
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json',
    "token": 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiQWlydGhlOTExIiwidGVybWluYWwiOiJQQyIsInRpbWVzdGFtcCI6MTY5ODQyMTEyNy42NTE5MDM0fQ._U25VW-L8d8Opysjxj-CV3Wm2XeZozxhHNiQDZvyR3U'
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
url = 'http://127.0.0.1:5000/auth/unregister'
  
data = {  
    "user_id": "Airthe911",  
    "password": "123456",
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
url = 'http://127.0.0.1:5000/auth/register'
data = {  
    "user_id": "Airthe911",  
    "password": "091101"  
}  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  

response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json() 
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
url = 'http://127.0.0.1:5000/auth/login'
  
data = {  
    "user_id": "Airthe911",  
    "password": "091101",
    "terminal": "PC"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok', 'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiQWlydGhlOTExIiwidGVybWluYWwiOiJQQyIsInRpbWVzdGFtcCI6MTY5ODQ2MDU1Mi45ODY5NTE4fQ.1xHMyEJw_2z7_V8Tre8hDKJ3yqSw_sh82WVdFnmDCqQ'}

# %%
cur = db["store"]
result = cur.find({"store_id": "test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707"})
for each in result:
    print(each)
    break
# Out:
# {'_id': ObjectId('653bbec8b6d7f247ac735789'), 'store_id': 'test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707', 'book_id': '1965143', 'book_info': '股票\n金融\n历史\n香港\n投资\n经济金融史\n经济\n财经\n', 'stock_level': 111}

# %%
url = 'http://127.0.0.1:5000/buyer/new_order'
  
data = {  
    "user_id": "Airthe911",  
    "store_id": "test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707",
    "books": [{"id": "1965143", "count": 1}]
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok', 'order_id': 'Airthe911_test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707_9e947fd2-7540-11ee-8b08-005056c00008'}

# %%
cur = db["new_order"]
result = cur.find({"user_id": "Airthe911"})
for each in result:
    print(each)

cur = db["user"]
result = cur.update_one({"user_id": "Airthe911"}, {"$set": {"balance": 666666}})
if result.matched_count == 0:
    print("加钱失败")
else:
    print("发财!")
# Out:
# {'_id': ObjectId('653c7b8ea0e422757c0ba3fa'), 'order_id': '', 'store_id': 'test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707', 'user_id': 'Airthe911'}
# {'_id': ObjectId('653c7cf1e7d78bf95f65f49a'), 'order_id': '', 'store_id': 'test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707', 'user_id': 'Airthe911'}
# {'_id': ObjectId('653c7d72f0d9fb6df9195aaa'), 'order_id': 'Airthe911_test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707_9e947fd2-7540-11ee-8b08-005056c00008', 'store_id': 'test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707', 'user_id': 'Airthe911'}
# 发财!

# %%
url = 'http://127.0.0.1:5000/buyer/payment'
  
data = {  
    "user_id": "Airthe911",  
    "order_id": 'Airthe911_test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707_9e947fd2-7540-11ee-8b08-005056c00008',
    "password": "091101"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
cur = db["new_order"]
result = cur.find({"user_id": "Airthe911"})
for each in result:
    print(each)
# Out:
# {'_id': ObjectId('653c7b8ea0e422757c0ba3fa'), 'order_id': '', 'store_id': 'test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707', 'user_id': 'Airthe911'}
# {'_id': ObjectId('653c7cf1e7d78bf95f65f49a'), 'order_id': '', 'store_id': 'test_add_books_store_id_84c5f24e-68c5-11ee-ac2d-f469d5c65707', 'user_id': 'Airthe911'}

# %%
cur = db["user"]
result = cur.find({"user_id": "Airthe911"})
for each in result:
    print(each["balance"])
url = 'http://127.0.0.1:5000/buyer/add_funds'
  
data = {  
    "user_id": "Airthe911",  
    "password": "091101",
    "add_value": 1028
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)  

result = cur.find({"user_id": "Airthe911"})
for each in result:
    print(each["balance"])
# Out:
# 671666
# {'message': 'ok'}
# 672694

# %%
cur = db["user_store"]
result = cur.find({"user_id": "Airthe911"})
for each in result:
    print(each)

url = 'http://127.0.0.1:5000/seller/create_store'
  
data = {  
    "user_id": "Airthe911",  
    "store_id": "李嘉豪的黑市"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)  

cur = db["user_store"]
result = cur.find({"user_id": "Airthe911"})
for each in result:
    print(each)
# Out:
# {'message': 'ok'}
# {'_id': ObjectId('653c88cc825e48f7ef90655a'), 'store_id': '李嘉豪的黑市', 'user_id': 'Airthe911'}

# %%
cur = db["book"]
result = cur.find()
count = 0
for each in result:
    print(each["id"], each["title"])
    count += 1
    if count == 10:
        break
# Out:
# 1361264 撒哈拉的故事
# 1036490 万水千山走遍
# 6710437 撒哈拉的故事
# 1029111 哭泣的骆驼
# 26997048 撒哈拉的故事
# 2068249 温柔的夜
# 6558705 雨季不再来
# 25803923 你是我不及的梦
# 3698390 送你一匹马
# 6558709 万水千山走遍

# %%
cur = db["user_store"]
result = cur.find({"store_id": "李嘉豪的黑市"})
for each in result:
    print(each)
# Out:
# {'_id': ObjectId('653c88cc825e48f7ef90655a'), 'store_id': '李嘉豪的黑市', 'user_id': 'Airthe911'}

# %%
cur = db["store"]
result = cur.find({"store_id": "李嘉豪的黑市"})
for each in result:
    print(each)

url = 'http://127.0.0.1:5000/seller/add_book'
  
data = {  
    "user_id": "Airthe911",  
    "store_id": "李嘉豪的黑市",
    "book_info": {"price": 30000, "id": "1036490"},
    "stock_level": 50
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
cur = db["store"]
result = cur.find({"store_id": "李嘉豪的黑市"})
for each in result:
    print(each)

url = 'http://127.0.0.1:5000/seller/add_stock_level'
  
data = {  
    "user_id": "Airthe911",  
    "store_id": "李嘉豪的黑市",
    "book_id": "1036490",
    "add_stock_level": 25
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)  

cur = db["store"]
result = cur.find({"store_id": "李嘉豪的黑市"})
for each in result:
    print(each)
# Out:
# {'_id': ObjectId('653c90556d9bb99a9cf13b90'), 'store_id': '李嘉豪的黑市', 'book_id': '1036490', 'book_info': '{"price": 30000, "id": "1036490"}', 'stock_level': 62}
# {'message': 'ok'}
# {'_id': ObjectId('653c90556d9bb99a9cf13b90'), 'store_id': '李嘉豪的黑市', 'book_id': '1036490', 'book_info': '{"price": 30000, "id": "1036490"}', 'stock_level': 87}

# %%
from datetime import datetime

# 获取当前时间戳
current_timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(type(current_timestamp))
print(current_timestamp)
# Out:
# <class 'str'>
# 2023-10-28 13:46:08

# %%
# 测试新加入的功能
url = 'http://127.0.0.1:5000/auth/register'
data = {  
    "user_id": "10204804434",  
    "password": "091101"  
}  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  

response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json() 
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
url = 'http://127.0.0.1:5000/auth/login'
  
data = {  
    "user_id": "10204804434",  
    "password": "091101",
    "terminal": "PC"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok', 'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiMTAyMDQ4MDQ0MzQiLCJ0ZXJtaW5hbCI6IlBDIiwidGltZXN0YW1wIjoxNjk4NDg0MDgxLjI0ODMzMjN9.cW4IvWGRi8OIFeXjeQeH4Lxwz7s4TpyaJu_Z9B52Xh4'}

# %%
cur = db["user"]
result = cur.find({"user_id": "10204804434"})
for each in result:
    print(each["balance"])
url = 'http://127.0.0.1:5000/buyer/add_funds'
  
data = {  
    "user_id": "10204804434",  
    "password": "091101",
    "add_value": 9999999
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)  

result = cur.find({"user_id": "10204804434"})
for each in result:
    print(each["balance"])
# Out:
# 0
# {'message': 'ok'}
# 9999999

# %%
url = 'http://127.0.0.1:5000/buyer/new_order'
  
data = {  
    "user_id": "10204804434",  
    "store_id": "李嘉豪的黑市",
    "books": [{"id": "1036490", "count": 5}]
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok', 'order_id': '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008'}

# %%
cur = db["new_order"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008"})
for each in result:
    print(each)

cur = db["new_order_detail"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008"})
for each in result:
    print(each)
# Out:
# {'_id': ObjectId('653ccf81def4ea4eaa6ef6d1'), 'order_id': '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008', 'store_id': '李嘉豪的黑市', 'user_id': '10204804434', 'payment_time': None}
# {'_id': ObjectId('653ccf81def4ea4eaa6ef6d0'), 'order_id': '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008', 'book_id': '1036490', 'count': 5, 'price': 1380, 'state': 0, 'order_time': '2023-10-28 17:08:17', 'payment_time': None, 'delivery_time': None, 'receipt_time': None}

# %%
cur = db["store"]
result = cur.find({"store_id": "李嘉豪的黑市"})
for each in result:
    print(each)
# Out:
# {'_id': ObjectId('653c90556d9bb99a9cf13b90'), 'store_id': '李嘉豪的黑市', 'book_id': '1036490', 'book_info': '{"price": 30000, "id": "1036490"}', 'stock_level': 77}

# %%
url = 'http://127.0.0.1:5000/buyer/payment'
  
data = {  
    "user_id": "10204804434",  
    "order_id": '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008',
    "password": "091101"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
cur = db["new_order"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008"})
for each in result:
    print(each)

cur = db["new_order_detail"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008"})
for each in result:
    print(each)
# Out:
# {'_id': ObjectId('653ccf81def4ea4eaa6ef6d1'), 'order_id': '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008', 'store_id': '李嘉豪的黑市', 'user_id': '10204804434', 'payment_time': '2023-10-28 17:09:39'}
# {'_id': ObjectId('653ccf81def4ea4eaa6ef6d0'), 'order_id': '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008', 'book_id': '1036490', 'count': 5, 'price': 1380, 'state': 1, 'order_time': '2023-10-28 17:08:17', 'payment_time': '2023-10-28 17:09:39', 'delivery_time': None, 'receipt_time': None}

# %%
url = 'http://127.0.0.1:5000/operations/delivery'
  
data = {  
    "order_id": '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008',
    "store_id": "李嘉豪的黑市",
    "store_owner_id": "Airthe911",
    "password": "091101"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)  

cur = db["new_order"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008"})
for each in result:
    print(each)

cur = db["new_order_detail"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008"})
for each in result:
    print(each)
# Out:
# {'message': 'ok'}
# {'_id': ObjectId('653ccf81def4ea4eaa6ef6d1'), 'order_id': '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008', 'store_id': '李嘉豪的黑市', 'user_id': '10204804434', 'payment_time': '2023-10-28 17:09:39'}
# {'_id': ObjectId('653ccf81def4ea4eaa6ef6d0'), 'order_id': '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008', 'book_id': '1036490', 'count': 5, 'price': 1380, 'state': 2, 'order_time': '2023-10-28 17:08:17', 'payment_time': '2023-10-28 17:09:39', 'delivery_time': '2023-10-28 17:10:07', 'receipt_time': None}

# %%
url = 'http://127.0.0.1:5000/operations/receipt'
  
data = {  
    "order_id": '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008',
    "user_id": "10204804434",
    "password": "091101"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)  

cur = db["new_order"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008"})
for each in result:
    print(each)

cur = db["new_order_detail"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008"})
for each in result:
    print(each)
# Out:
# {'message': 'ok'}
# {'_id': ObjectId('653ccf81def4ea4eaa6ef6d1'), 'order_id': '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008', 'store_id': '李嘉豪的黑市', 'user_id': '10204804434', 'payment_time': '2023-10-28 17:09:39'}
# {'_id': ObjectId('653ccf81def4ea4eaa6ef6d0'), 'order_id': '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008', 'book_id': '1036490', 'count': 5, 'price': 1380, 'state': 3, 'order_time': '2023-10-28 17:08:17', 'payment_time': '2023-10-28 17:09:39', 'delivery_time': '2023-10-28 17:10:07', 'receipt_time': '2023-10-28 17:10:21'}

# %%
url = 'http://127.0.0.1:5000/operations/lookup'
  
data = {  
    "order_id": '10204804434_李嘉豪的黑市_783422cb-7565-11ee-a5b4-005056c00008',
    "user_id": "10204804434",
    "password": "091101"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': "{'_id': ObjectId('653cbb4d0553e1f06391146b'), 'order_id': '10204804434_李嘉豪的黑市_783422cb-7565-11ee-a5b4-005056c00008', 'book_id': '1036490', 'count': 2, 'price': 1380, 'state': 3, 'order_time': '2023-10-28 15:42:05', 'delivery_time': '2023-10-28 15:46:33', 'receipt_time': '2023-10-28 15:48:26'}"}

# %%
url = 'http://127.0.0.1:5000/operations/cancer'
  
data = {  
    "order_id": '10204804434_李嘉豪的黑市_8678fba0-7571-11ee-a52f-005056c00008',
    "user_id": "10204804434",
    "password": "091101"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  

response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# 请求失败，状态码： 911
# {'message': '只有处于未付款的订单才能进行本操作'}

# %%
url = 'http://127.0.0.1:5000/buyer/new_order'
  
data = {  
    "user_id": "10204804434",  
    "store_id": "李嘉豪的黑市",
    "books": [{"id": "1036490", "count": 3}]
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok', 'order_id': '10204804434_李嘉豪的黑市_d8d1ca44-7567-11ee-8bfc-005056c00008'}

# %%
cur = db["new_order"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_d8d1ca44-7567-11ee-8bfc-005056c00008"})
for each in result:
    print(each)

cur = db["new_order_detail"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_d8d1ca44-7567-11ee-8bfc-005056c00008"})
for each in result:
    print(each)
# Out:
# {'_id': ObjectId('653cbf435f1d7cf59eae9225'), 'order_id': '10204804434_李嘉豪的黑市_d8d1ca44-7567-11ee-8bfc-005056c00008', 'store_id': '李嘉豪的黑市', 'user_id': '10204804434'}
# {'_id': ObjectId('653cbf435f1d7cf59eae9224'), 'order_id': '10204804434_李嘉豪的黑市_d8d1ca44-7567-11ee-8bfc-005056c00008', 'book_id': '1036490', 'count': 3, 'price': 1380, 'state': 0, 'order_time': '2023-10-28 15:58:59', 'delivery_time': 'not_set_yet', 'receipt_time': 'not_set_yet'}

# %%
url = 'http://127.0.0.1:5000/operations/cancer'
  
data = {  
    "order_id": '10204804434_李嘉豪的黑市_d8d1ca44-7567-11ee-8bfc-005056c00008',
    "user_id": "10204804434",
    "password": "091101"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': 'ok'}

# %%
cur = db["new_order"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_d8d1ca44-7567-11ee-8bfc-005056c00008"})
for each in result:
    print(each)

cur = db["new_order_detail"]
result = cur.find({"order_id": "10204804434_李嘉豪的黑市_d8d1ca44-7567-11ee-8bfc-005056c00008"})
for each in result:
    print(each)

# %%
db["book"].create_index([("title", "text"), ("book intro", "text"), ("content", "text"), ("tags", "text")])
# Out:
# 'title_text_book intro_text_content_text_tags_text'

# %%
url = 'http://127.0.0.1:5000/operations/search'
  
data = {  
    "keyword": "撒哈拉",
    "how": "global"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  
  
response = requests.post(url, data=json_data, headers=headers)  
  
if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': '标题: 绝地撒哈拉, 作者: 金飞豹, 介绍: ●2009年，著名探险家金飞豹和地质专家费宣用80天时间成功完成穿越世界第一大沙漠撒哈拉沙漠的壮举。全程6700公里，穿越6个异域国度，用独木舟和骆驼徒步走过蛮荒沙漠，留下6万字真情记录和150张高清图片，告诉你一个真实的撒哈拉。\n●失去联络的3天、悬崖上的村庄、三毛看到的蓝皮人、神秘部落的盛会、不明的审判……\n●“20多年的户外行走生涯，让我深刻的领悟到了人生的真谛，世界上没有比心更高的山峰，也没有比脚步更远的道路。” “梦想”始终是金飞豹想要传递给每一位行走人的话。“我要一直走下去，直到我老得走不动了；但即使老得走不动了，我也要用文字将我的行走和记录下来。只要有梦想，探寻的脚步就永不停歇。”\n●在以最快速度完成世界7+2项目之后，世界上最干燥炎热的非洲腹地——撒哈拉成为了他下一站梦想的实现地。在哪里，金飞豹不仅完成了中国人首次的撒哈拉腹地穿越，他...\n, 出版年份: 2012-9\n标题: 撒哈拉的故事, 作者: 三毛, 介绍: ★搁笔十年之后首次以“三毛”笔名面向读者之作\n★流浪文学经典 畅销三十余年热度不减\n★与荷西传奇爱情的见证 唤起万千人心中的撒哈拉之梦\n在三毛的内心深处，撒哈拉沙漠是梦中情人，是不能解释的，属于前世回忆似的乡愁，莫名其妙，她毫无保留地把自己交给了那一片陌生的大地。每一粒沙地里的石子，尚且知道珍爱它，每一次日出和日落，都舍不得忘怀，更何况，这一张张活生生的脸孔，又如何能在回忆里抹去他们。\n《撒哈拉的故事》是三毛最脍炙人口的散文佳作。在适应了撒哈拉大漠枯燥、单调的生活之后，她重新提笔写作，记录与荷西苦中作乐的婚姻生活、撒哈拉威人的异域文化，以及沙漠地带的动荡局势……十几篇质朴的散文，洋溢着旺盛的生命力，倾倒了全世界的华文读者。\n, 出版年份: 2017-3-1\n标题: 路上有微光, 作者: 猫力，卤猫 著作, 介绍: 《猫力乱步》后，猫力一直在路上\n五年，数十个国家\n浓缩成九个照亮旅途的暖心故事\n插画师卤猫，首次与猫力合作\n治愈性画笔，再现每个故事的诗意瞬间\n随书附赠猫力签名明信片、手绘旅行地图\n《路上有微光》是《猫力乱步》作者猫力最新的作品。五年来，猫力继续在路上，陆续游走伊朗、印度、英国、墨西哥、古巴、埃及等数十国家。她将所见
# ...

# %%
url = 'http://127.0.0.1:5000/operations/search'
  
data = {  
    "keyword": "万水千山走遍",
    "how": "local", 
    "store_id": "李嘉豪的黑市"
}  
  
json_data = json.dumps(data)  
  
headers = {  
    'Content-Type': 'application/json'  
}  

response = requests.post(url, data=json_data, headers=headers)  

if response.status_code == 200:  
    response_data = response.json()
    print(response_data)  
else:  
    print('请求失败，状态码：', response.status_code)
    response_data = response.json()
    print(response_data)
# Out:
# {'message': '标题: 万水千山走遍, 作者: 三毛, 介绍: 大地啊，我来到你岸上时原是一个陌生人，住在你房子里时原是一个旅客，而今我离开你的门时却是一个朋友了。 当飞机降落在墨西哥首都的机场时，我的体力已经透支得几乎无法举步。长长的旅程，别人睡觉，我一直在看书。眼看全机的人都慢慢地走了，还让自己绑在安全带上。窗外的机场灯光通明，是夜间了。\n, 出版年份: 2003-08\n'}

# %%
cur = db["book"]
result = cur.find({"id":{ "$in": ["1036490"]}})
for each in result:
    print(each["id"])
    print(type(each["id"]))
    break
# Out:
# 1036490
# <class 'str'>

# %%
cur = db["book"]
result = cur.find({"id":{ "$in": ["1036490"]}, "$text": {"$search": "巴拿马"}})
for each in result:
    print(each)
    break
# Out:
# {'_id': ObjectId('653bb4f6b6d7f247ac72abb5'), 'id': '1036490', 'title': '万水千山走遍', 'author': '三毛', 'publisher': '哈尔滨出版社', 'original_title': None, 'translator': None, 'pub_year': '2003-08', 'pages': 215, 'price': 1380, 'currency_unit': '', 'binding': '平装', 'isbn': '9787806399057', 'author_intro': '三毛：台湾著名作家，1943年3月26日出生于重庆，浙江省定海县人。本名为陈惠平，1946年改名陈平，笔名“三毛”。1964年进入文化大学哲学系，肄业后曾留学欧洲，婚后定居西属撒哈拉沙漠加那利岛并以当地的生活为背景，写出一连串情感真挚的作品。1981年回到台湾，曾在文化大学任教，1984年辞去教职，专职从事写作和演讲。1991年1月4日去世，享年48岁。\n', 'book_intro': '大地啊，我来到你岸上时原是一个陌生人，住在你房子里时原是一个旅客，而今我离开你的门时却是一个朋友了。 当飞机降落在墨西哥首都的机场时，我的体力已经透支得几乎无法举步。长长的旅程，别人睡觉，我一直在看书。眼看全机的人都慢慢地走了，还让自己绑在安全带上。窗外的机场灯光通明，是夜间了。\n', 'content': '一 墨西哥纪行\n1 大蜥蜴之夜\n2 街头巷尾\n二 洪都拉斯纪行\n1 青鸟不到的地方\n三 哥斯达黎加纪行\n1 中美洲的花园\n四 巴拿马纪行\n1 美妮表妹\n五 哥伦比亚纪行\n1 一个不按牌理出牌的地方\n2 附记：一封给邓念慈神父的信\n六 厄瓜多尔纪行\n1 药师的孙女――前世\n2 银湖之滨――今生\n七 秘鲁纪行\n1 索诺奇――雨原之一\n2 夜戏――雨原之二\n3 迷城――雨原之三\n4 逃水――雨原之四\n八 附录\n1 飞越纳斯加之线\n2 三毛一生大事记\n· · · · · ·     (\n)\n', 'tags': '三毛\n万水千山走遍\n旅行\n散文\n游记\n随笔\n流浪\n台湾\n', 'picture': b'\xff\xd8\xff\
# ...
